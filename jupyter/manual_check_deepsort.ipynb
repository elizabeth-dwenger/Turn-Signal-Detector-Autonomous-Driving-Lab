# %%
from deepsort_sequence_editor import SequenceCleaningTool

# %%
tool = SequenceCleaningTool(
    csv_path="../final_corrected_tracks_filtered.csv",
    base_path="/",     
    max_sequences=5000,
    autosave_file="autosave_state.json"
)

# %%
tool.display()

# %%
# import pandas as pd
# import json
# import numpy as np

# df = pd.read_csv("cleaned_data_20251209_230609.csv")

# with open("autosave_state.json") as f:
#     j = json.load(f)

# selected_ids_5k = set(j["selected_seq_ids"]) 
# filtered_df_5k = df[df["sequence_id"].isin(selected_ids_5k)]

# cutoff = "2024-09-05-13-41-48_mapping_tartu_streets_traffic_lights_ouster_lidar/camera_narrow_front_2363"

# seq_list = j["selected_seq_ids"]

# if cutoff in seq_list:
#     cutoff_index = seq_list.index(cutoff)
#     limited_seq_ids = seq_list[:cutoff_index] 
# else:
#     raise ValueError("Cutoff sequence_id not found in JSON")

# selected_ids = set(limited_seq_ids)

# filtered_df = df[df["sequence_id"].isin(selected_ids)]

# value_counts = filtered_df["predicted_label"].value_counts()

# print(value_counts)

# %%
# filtered_df.head()

# %%
# images_per_sequence = filtered_df.groupby("sequence_id").size()

# small_sequences = images_per_sequence[images_per_sequence < 5]
# len(small_sequences)
# len(images_per_sequence)

# %%
# images_per_sequence = filtered_df.groupby("sequence_id").size()

# valid_sequences = images_per_sequence[images_per_sequence >= 5].index

# clean_filtered_df = filtered_df[filtered_df["sequence_id"].isin(valid_sequences)]

# clean_filtered_df.to_csv("filtered_1010.csv", index=False)

# print("Saved filtered_1010.csv with", len(clean_filtered_df), "rows.")

# %%
# print(f"Checked: {len(clean_filtered_df)}")
# print(f"Left to check: {len(filtered_df_5k) - len(clean_filtered_df)}")
