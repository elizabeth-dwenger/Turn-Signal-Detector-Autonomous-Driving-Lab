# %% [markdown]
# # OpenAI API Labeling for Sequences

# %%
from sequence_openai_labeling_01 import *

# %%
df = pd.read_csv('../labels_output/labels_lstm.csv')
test_path = df['crop_path'].iloc[0]
full_path = Path(str('../seq_img' + test_path))
print(f"Original path: {test_path}")
print(f"Full path: {full_path}")
print(f"Exists: {full_path.exists()}")
# Out:
# Original path: /gpfs/space/projects/ml2024/2024-08-16-16-03-30_mapping_tartu_streets/camera_narrow_front/predict/crops/car/142120.jpg
# Full path: ../seq_img/gpfs/space/projects/ml2024/2024-08-16-16-03-30_mapping_tartu_streets/camera_narrow_front/predict/crops/car/142120.jpg
# Exists: True

# %%
test_seq = df[df['sequence_id'] == 'seq_0000'].sort_values('frame_idx')
test_paths = [str('../seq_img' + test_path) for p in test_seq['crop_path'].tolist()]
print(f"Testing with {len(test_paths)} frames")
print(f"First frame exists: {Path(test_paths[0]).exists()}")
# Out:
# Testing with 13 frames
# First frame exists: True

# %%
result_individual = label_sequence_individual_frames(test_paths, model='gpt-4o-mini')
print(json.dumps(result_individual, indent=2))
# Out:
# {
#   "label": "none",
#   "confidence": 1.0,
#   "reasoning": "Throughout all frames, there are no visible turn signals blinking on either side of the vehicle. The lights remain off, indicating that no turn signals are active.",
#   "frames_with_signal": [],
#   "method": "individual_frames",
#   "num_frames": 13,
#   "model": "gpt-4o-mini",
#   "tokens_used": {
#     "prompt": 184502,
#     "completion": 50,
#     "total": 184552
#   }
# }

# %%
result_grid = label_sequence_grid(test_paths, model='gpt-4o-mini')
print(json.dumps(result_grid, indent=2))
# Out:
# {
#   "label": "none",
#   "confidence": 0.95,
#   "reasoning": "Throughout the sequence, there are no visible amber/orange lights indicating that the turn signals are active. The lights appear to be off in all frames.",
#   "frames_with_signal": [],
#   "method": "grid",
#   "num_frames": 13,
#   "model": "gpt-4o-mini",
#   "tokens_used": {
#     "prompt": 48474,
#     "completion": 49,
#     "total": 48523
#   }
# }

# %%
results_df = process_all_sequences(
    label_csv='../labels_output/labels_lstm.csv',
    method='both',
    model='gpt-4o-mini',
    output_path='openai_results.json',
    image_base_path='../seq_img' 
)
# Out:
# Processing 21 sequences using method: both
# Model: gpt-4o
# Image base path: ../seq_img
# ------------------------------------------------------------
#
# [1/21] Processing seq_0000...
#   True label: right
#   Frames: 4
#   First frame: 142120.jpg
#   Running individual frames method...
#     Predicted: none
#   Running grid method...
#     Predicted: none
#
# [2/21] Processing seq_0001...
#   True label: left
#   Frames: 4
#   First frame: 087883.jpg
#   Running individual frames method...
#     Predicted: none
#   Running grid method...
#     Predicted: right
#
# [3/21] Processing seq_0002...
#   True label: left
#   Frames: 4
#   First frame: 0510122.jpg
#   Running individual frames method...
#     Predicted: none
#   Running grid method...
#     Predicted: none
#
# [4/21] Processing seq_0003...
#   True label: right
#   Frames: 4
#   First frame: 0017802.jpg
#   Running individual frames method...
#     Predicted: right
#   Running grid method...
#     Predicted: left
#
# [5/21] Processing seq_0004...
#   True label: right
#   Frames: 4
#   First frame: 074251.jpg
#   Running individual frames method...
#     Predicted: none
#   Running grid method...
#     Predicted: none
#
# [6/21] Processing seq_0005...
#   True label: left
#   Frames: 4
#   First frame: 065991.jpg
#   Running individual frames method...
#     Predicted: left
#   Running grid method...
#     Predicted: left
#
# [7/21] Processing seq_0006...
#   True label: left
#   Frames: 4
#   First frame: 087974.jpg
#   Running individual frames method...
#     Predicted: none
#   Running grid method...
#     Predicted: none
#
# [8/21] Processing seq_0007...
#   True label: right
#   Frames: 4
#   First frame: 074292.jpg
#   Running individual frames method...
#     Predicted: none
#   Running grid method...
#     Predicted: none
#
# [9/21] Processing seq_0008...
#   True label: right
#   Frames: 4
#   First frame: 002068.jpg
#   Running individual frames method...
#     Predicted: right
#   Running grid method...
#     Predicted: right
#
# [10/21] Processing seq_0009...
#   True label: left
#   Frames: 4
#   First frame: 055068.jpg
#   Running individual frames method...
#     Predicted: none
#   Running grid method...
#     Predicted: none
#
# [11/21] Processing seq_0010...
#   True label: hazard
#   Frames: 4
#   First frame: 014900.jpg
#   Running individual frames method...
#     Predicted: right
#   Running grid method...
#     Predicted: none
#
# [12/21] Processing seq_0011...
#   True label: none
#   Frames: 4
#   First frame: 019751.jpg
#   Running individual frames method...
#     Predicted: none
#   Running grid method...
#     Predicted: error
#
# [13/21] Processing seq_0012...
#   True label: none
#   Frames: 4
#   First frame: 0614282.jpg
#   Running individual frames method...
#     Predicted: hazard
#   Running grid method...
#     Predicted: right
#
# [14/21] Processing seq_0013...
#   True label: none
#   Frames: 4
#   First frame: 0083573.jpg
#   Running individual frames method...
#     Predicted: none
#   Running grid method...
#     Predicted: none
#
# [15/21] Processing seq_0014...
#   True label: none
#   Frames: 4
#   First frame: 008699.jpg
#   Running individual frames method...
#     Predicted: none
#   Running grid method...
#     Predicted: none
#
# [16/21] Processing seq_0015...
#   True label: none
#   Frames: 4
#   First frame: 0906622.jpg
#   Running individual frames method...
#     Predicted: none
#   Running grid method...
#     Predicted: error
#
# [17/21] Processing seq_0016...
#   True label: none
#   Frames: 4
#   First frame: 0026083.jpg
#   Running individual frames method...
#     Predicted: left
#   Running grid method...
#     Predicted: none
#
# [18/21] Processing seq_0017...
#   True label: none
#   Frames: 4
#   First frame: 0046732.jpg
#   Running individual frames method...
#     Predicted: left
#   Running grid method...
#     Predicted: none
#
# [19/21] Processing seq_0018...
#   True label: none
#   Frames: 4
#   First frame: 007568.jpg
#   Running individual frames method...
#     Predicted: none
#   Running grid method...
#     Predicted: none
#
# [20/21] Processing seq_0019...
#   True label: none
#   Frames: 4
#   First frame: 052689.jpg
#   Running individual frames method...
#     Predicted: none
#   Running grid method...
#     Predicted: right
#
# [21/21] Processing seq_0020...
#   True label: none
#   Frames: 4
#   First frame: 0057972.jpg
#   Running individual frames method...
#     Predicted: none
#   Running grid method...
#     Predicted: none
#
# ============================================================
# Results saved to: openai_gpt4o_results.json

# %%
metrics = evaluate_results(results_df)
# Out:
# Individual Frames Method:
#   Accuracy: 47.62% (10/21)
#   Confusion Matrix:
# individual  hazard  left  none  right
# true_label
# hazard           0     0     0      1
# left             0     1     4      0
# none             1     2     7      0
# right            0     0     3      2
#
# Grid Method:
#   Accuracy: 38.10% (8/21)
#   Confusion Matrix:
# grid        error  left  none  right
# true_label
# hazard          0     0     1      0
# left            0     1     3      1
# none            2     0     6      2
# right           0     1     3      1

# %%
errors = results_df[
    results_df['individual'].apply(lambda x: x.get('label')) != results_df['true_label']
]
print(f"Found {len(errors)} errors")
for idx, row in errors.iterrows():
    print(f"\nSequence: {row['sequence_id']}")
    print(f"True: {row['true_label']}, Predicted: {row['individual']['label']}")
    print(f"Reasoning: {row['individual']['reasoning']}")
# Out:
# Found 11 errors
#
# Sequence: seq_0000
# True: right, Predicted: none
# Reasoning: The amber lights on both sides of the car are consistently on in all frames, indicating that no turn signals are blinking. This suggests that the lights are not being used as turn signals or hazard lights, but are likely just the regular tail lights.
#
# Sequence: seq_0001
# True: left, Predicted: none
# Reasoning: The amber lights on both sides of the car are consistently on in all frames, indicating that there is no blinking pattern. This suggests that no turn signals are active, as turn signals would blink on and off.
#
# Sequence: seq_0002
# True: left, Predicted: none
# Reasoning: The amber lights on both sides of the car are consistently on in all frames, indicating that they are not blinking. This suggests that no turn signals are active, as blinking is required to indicate active turn signals.
#
# Sequence: seq_0004
# True: right, Predicted: none
# Reasoning: In all frames, both the left and right amber lights are consistently on, indicating that there is no blinking pattern. This suggests that no turn signals are active.
#
# Sequence: seq_0006
# True: left, Predicted: none
# Reasoning: The amber lights on both sides of the car are consistently on in all frames, indicating that there is no blinking pattern. This suggests that no turn signals are active.
#
# Sequence: seq_0007
# True: right, Predicted: none
# Reasoning: The amber lights on both sides of the car are consistently on in all frames, indicating that they are not blinking. This suggests that no turn signals are active, as blinking is required to indicate active signals.
#
# Sequence: seq_0009
# True: left, Predicted: none
# Reasoning: In all frames, both the left and right amber lights are consistently on, indicating that there is no blinking pattern. This suggests that no turn signals are active.
#
# Sequence: seq_0010
# True: hazard, Predicted: right
# Reasoning: The right amber light is blinking in frames 1 and 3, indicating the right turn signal is active. The left light remains off in all frames.
#
# Sequence: seq_0012
# True: none, Predicted: hazard
# Reasoning: Both left and right amber lights are blinking in frame 3, indicating hazard lights are active.
#
# Sequence: seq_0016
# True: none, Predicted: left
# Reasoning: The amber light on the left side of the car is blinking in frames 0 and 2, indicating the left turn signal is active. The light is off in frames 1 and 3, showing the blinking pattern.
#
# Sequence: seq_0017
# True: none, Predicted: left
# Reasoning: The amber light on the left side of the car is blinking in frames 0 and 2, indicating the left turn signal is active.

# %% [markdown]
# # Visualization

# %%
import matplotlib.pyplot as plt
import textwrap

# %%
def visualize_comparison(
    image_paths: List[str],
    individual_result: Dict,
    grid_result: Dict,
    true_label: str = None,
    figsize: Tuple[int, int] = (18, 12)
):
    fig = plt.figure(figsize=figsize)
    
    # Create grid layout
    gs = fig.add_gridspec(3, 2, height_ratios=[0.15, 1, 0.5], hspace=0.3, wspace=0.2)
    
    # Title
    title_ax = fig.add_subplot(gs[0, :])
    title_ax.axis('off')
    title_text = f"SEQUENCE COMPARISON"
    if true_label:
        title_text += f" | True Label: {true_label.upper()}"
    title_ax.text(0.5, 0.5, title_text, ha='center', va='center', 
                 fontsize=16, fontweight='bold')
    
    # Individual method images
    individual_ax = fig.add_subplot(gs[1, 0])
    individual_ax.axis('off')
    individual_ax.set_title("INDIVIDUAL FRAMES METHOD", fontweight='bold', fontsize=12)
    
    # Create mini grid for individual
    n_images = len(image_paths)
    n_cols = min(3, n_images)
    n_rows = (n_images + n_cols - 1) // n_cols
    
    mini_fig_individual = create_image_grid(image_paths, max_cols=n_cols)
    individual_ax.imshow(mini_fig_individual)
    
    # Grid method image
    grid_ax = fig.add_subplot(gs[1, 1])
    grid_ax.axis('off')
    grid_ax.set_title("GRID METHOD", fontweight='bold', fontsize=12)
    
    grid_image = create_image_grid(image_paths, max_cols=min(5, n_images))
    grid_ax.imshow(grid_image)
    
    # Individual results text
    individual_text_ax = fig.add_subplot(gs[2, 0])
    individual_text_ax.axis('off')
    
    ind_text = format_result_text(individual_result, true_label, "Individual")
    individual_text_ax.text(0, 1, ind_text, 
                           verticalalignment='top',
                           fontsize=10,
                           family='monospace',
                           bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
    
    # Grid results text
    grid_text_ax = fig.add_subplot(gs[2, 1])
    grid_text_ax.axis('off')
    
    grid_text = format_result_text(grid_result, true_label, "Grid")
    grid_text_ax.text(0, 1, grid_text,
                     verticalalignment='top',
                     fontsize=10,
                     family='monospace',
                     bbox=dict(boxstyle='round', facecolor='lightgreen', alpha=0.8))
    
    return fig


def format_result_text(result: Dict, true_label: str = None, method_name: str = "") -> str:
    """Format result dictionary as readable text."""
    text = f"{method_name.upper()} RESULTS\n{'='*40}\n\n"
    
    predicted = result.get('label', 'error').upper()
    
    if true_label:
        match = "✓ CORRECT" if result.get('label') == true_label else "✗ INCORRECT"
        text += f"True: {true_label.upper()}\n"
        text += f"Predicted: {predicted} ({match})\n\n"
    else:
        text += f"Predicted: {predicted}\n\n"
        
    if 'reasoning' in result:
        wrapped = textwrap.fill(result['reasoning'], width=35)
        text += f"Reasoning:\n{wrapped}\n\n"
    
    if 'frames_with_signal' in result:
        text += f"Signal frames: {result['frames_with_signal']}\n\n"
    
    if 'error' in result:
        text += f"\nERROR: {result['error']}\n"
    
    return text

# %%
seq_idx = 2  # Change this to view different sequences
row = results_df.iloc[seq_idx]
image_paths = [str(p) for p in row['frame_paths']]

if 'individual' in row and 'grid' in row:
    fig = visualize_comparison(
        image_paths, 
        row['individual'], 
        row['grid'], 
        row['true_label']
    )
    plt.show()

# Cell 11: Analyze only errors with visualization
errors = results_df[
    results_df['individual'].apply(lambda x: x.get('label') if isinstance(x, dict) else None) 
    != results_df['true_label']
]
