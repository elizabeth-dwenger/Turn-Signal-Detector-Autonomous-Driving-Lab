# %% [markdown]
# # Visualizing some outputs from ByteTrack

# %%
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import os
from IPython.display import display, clear_output, HTML
import time
import glob

# %%
CSV_PATH = "../tracks_with_crops_tuned_01.csv"
LOCAL_CROPS_DIR = "../ByteTrack_images/"

# %%
# Load the CSV
df = pd.read_csv(CSV_PATH)
df["frame_id_int"] = df["frame_id"].astype(int)
df = df.sort_values(["sequence", "track_id", "frame_id_int"])

# %%
# Add a column for local file paths (just the filename)
df["crop_filename"] = df["crop_path"].apply(lambda x: os.path.basename(x))
df["local_path"] = df["crop_filename"].apply(lambda x: os.path.join(LOCAL_CROPS_DIR, x))

# %%
# Check which files actually exist locally
df["exists_locally"] = df["local_path"].apply(os.path.exists)

print(f"Total rows in CSV: {len(df)}")
print(f"Files available locally: {df['exists_locally'].sum()}")
print(f"Files in {LOCAL_CROPS_DIR}: {len(glob.glob(os.path.join(LOCAL_CROPS_DIR, '*.jpg')))}")
# Out:
# Total rows in CSV: 690719
# Files available locally: 28
# Files in ../ByteTrack_images/: 28

# %%
# Get tracks that have local images
local_tracks = df[df["exists_locally"]].groupby(["sequence", "track_id"]).size()
local_tracks = local_tracks[local_tracks >= 3].sort_values(ascending=False)  # At least 3 frames

print(f"\nTracks with local images (3+ frames):")
for (seq, tid), count in local_tracks.head(10).items():
    print(f"  Sequence: {seq}, Track ID: {tid}, Frames: {count}")
# Out:
# Tracks with local images (3+ frames):
#   Sequence: 2024-03-25-15-40-16_mapping_tartu/camera_fl, Track ID: 2, Frames: 13
#   Sequence: 2024-03-25-15-40-16_mapping_tartu/camera_fl, Track ID: 1, Frames: 11
#   Sequence: 2024-03-25-15-40-16_mapping_tartu/camera_fl, Track ID: 3, Frames: 4

# %%
df.head(20)
# Out:
#                                        sequence  track_id  frame_id  class_id  \
# 0   2024-03-25-15-40-16_mapping_tartu/camera_fl         1         0         2
# 1   2024-03-25-15-40-16_mapping_tartu/camera_fl         1         1         2
# 2   2024-03-25-15-40-16_mapping_tartu/camera_fl         1         2         2
# 3   2024-03-25-15-40-16_mapping_tartu/camera_fl         1         3         2
# 4   2024-03-25-15-40-16_mapping_tartu/camera_fl         1         4         2
# 5   2024-03-25-15-40-16_mapping_tartu/camera_fl         1         5         2
# 6   2024-03-25-15-40-16_mapping_tartu/camera_fl         1         6         2
# 7   2024-03-25-15-40-16_mapping_tartu/camera_fl         1         7         2
# 8   2024-03-25-15-40-16_mapping_tartu/camera_fl         1         8         2
# 9   2024-03-25-15-40-16_mapping_tartu/camera_fl         1         9         2
# 10  2024-03-25-15-40-16_mapping_tartu/camera_fl         1        10         2
# 11  2024-03-25-15-40-16_mapping_tartu/camera_fl         1        11         2
# 12  2024-03-25-15-40-16_mapping_tartu/camera_fl         1        12         2
# 13  2024-03-25-15-40-16_mapping_tartu/camera_fl         1        13         2
# 14  2024-03-25-15-40-16_mapping_tartu/camera_fl         1        14         2
# 15  2024-03-25-15-40-16_mapping_tartu/camera_fl         1        15         2
# 16  2024-03-25-15-40-16_mapping_tartu/camera_fl         1        16         2
# 17  2024-03-25-15-40-16_mapping_tartu/camera_fl         2         0         2
# 18  2024-03-25-15-40-16_mapping_tartu/camera_fl         2         1         2
# 19  2024-03-25-15-40-16_mapping_tartu/camera_fl         2         2         2
#
#        score    x1    y1    x2    y2  \
# 0   0.896628   826  1228  1013  1367
# 1   0.902721   813  1228  1006  1367
# 2   0.903672   800  1227   998  1364
# 3   0.895926   784  1227   988  1363
# 4   0.906801   766  1227   976  1361
# 5   0.884779   748  1228   963  1360
# 6   0.892543   727  1227   950  1359
# 7   0.878652   707  1229   933  1357
# 8   0.886926   684  1225   913  1354
# 9   0.898587   660  1226   896  1353
# 10  0.908758   636  1223   876  1351
# 11  0.911782   610  1224   855  1351
# 12  0.899557   581  1224   831  1349
# 13  0.905981   555  1224   806  1347
# 14  0.896577   523  1221   779  1344
# 15  0.902547   494  1221   752  1342
# 16  0.890992   462  1220   725  1340
# 17  0.903152  1138  1244  1451  1517
# 18  0.905231  1138  1244  1451  1517
# 19  0.904591  1138  1244  1452  1516
#
#                                             crop_path  \
# 0   /gpfs/space/projects/ml2024/2024-03-25-15-40-1...
# 1   /gpfs/space/projects/ml2024/2024-03-25-15-40-1...
# 2   /gpfs/space/projects/ml2024/2024-03-25-15-40-1...
# 3   /gpfs/space/projects/ml2024/2024-03-25-15-40-1...
# 4   /gpfs/space/projects/ml2024/2024-03-25-15-40-1...
# 5   /gpfs/space/projects/ml2024/2024-03-25-15-40-1...
# 6   /gpfs/space/projects/ml2024/2024-03-25-15-40-1...
# 7   /gpfs/space/projects/ml2024/2024-03-25-15-40-1...
# 8   /gpfs/space/projects/ml2024/2024-03-25-15-40-1...
# 9   /gpfs/space/projects/ml2024/2024-03-25-15-40-1...
# 10  /gpfs/space/projects/ml2024/2024-03-25-15-40-1...
# 11  /gpfs/space/projects/ml2024/2024-03-25-15-40-1...
# 12  /gpfs/space/projects/ml2024/2024-03-25-15-40-1...
# 13  /gpfs/space/projects/ml2024/2024-03-25-15-40-1...
# 14  /gpfs/space/projects/ml2024/2024-03-25-15-40-1...
# 15  /gpfs/space/projects/ml2024/2024-03-25-15-40-1...
# 16  /gpfs/space/projects/ml2024/2024-03-25-15-40-1...
# 17  /gpfs/space/projects/ml2024/2024-03-25-15-40-1...
# 18  /gpfs/space/projects/ml2024/2024-03-25-15-40-1...
# 19  /gpfs/space/projects/ml2024/2024-03-25-15-40-1...
#
#                                              img_path  width  height  \
# 0   /gpfs/space/projects/ml2024/2024-03-25-15-40-1...   2064    1544
# 1   /gpfs/space/projects/ml2024/2024-03-25-15-40-1...   2064    1544
# 2   /gpfs/space/projects/ml2024/2024-03-25-15-40-1...   2064    1544
# 3   /gpfs/space/projects/ml2024/2024-03-25-15-40-1...   2064    1544
# 4   /gpfs/space/projects/ml2024/2024-03-25-15-40-1...   2064    1544
# 5   /gpfs/space/projects/ml2024/2024-03-25-15-40-1...   2064    1544
# 6   /gpfs/space/projects/ml2024/2024-03-25-15-40-1...   2064    1544
# 7   /gpfs/space/projects/ml2024/2024-03-25-15-40-1...   2064    1544
# 8   /gpfs/space/projects/ml2024/2024-03-25-15-40-1...   2064    1544
# 9   /gpfs/space/projects/ml2024/2024-03-25-15-40-1...   2064    1544
# 10  /gpfs/space/projects/ml2024/2024-03-25-15-40-1...   2064    1544
# 11  /gpfs/space/projects/ml2024/2024-03-25-15-40-1...   2064    1544
# 12  /gpfs/space/projects/ml2024/2024-03-25-15-40-1...   2064    1544
# 13  /gpfs/space/projects/ml2024/2024-03-25-15-40-1...   2064    1544
# 14  /gpfs/space/projects/ml2024/2024-03-25-15-40-1...   2064    1544
# 15  /gpfs/space/projects/ml2024/2024-03-25-15-40-1...   2064    1544
# 16  /gpfs/space/projects/ml2024/2024-03-25-15-40-1...   2064    1544
# 17  /gpfs/space/projects/ml2024/2024-03-25-15-40-1...   2064    1544
# 18  /gpfs/space/projects/ml2024/2024-03-25-15-40-1...   2064    1544
# 19  /gpfs/space/projects/ml2024/2024-03-25-15-40-1...   2064    1544
#
#     frame_id_int crop_filename                       local_path  \
# 0              0   0000002.jpg  ../ByteTrack_images/0000002.jpg
# 1              1   0000012.jpg  ../ByteTrack_images/0000012.jpg
# 2              2   0000022.jpg  ../ByteTrack_images/0000022.jpg
# 3              3   0000032.jpg  ../ByteTrack_images/0000032.jpg
# 4              4   0000042.jpg  ../ByteTrack_images/0000042.jpg
# 5              5   0000058.jpg  ../ByteTrack_images/0000058.jpg
# 6              6   0000062.jpg  ../ByteTrack_images/0000062.jpg
# 7              7   0000075.jpg  ../ByteTrack_images/0000075.jpg
# 8              8   0000086.jpg  ../ByteTrack_images/0000086.jpg
# 9              9   0000092.jpg  ../ByteTrack_images/0000092.jpg
# 10            10    000010.jpg   ../ByteTrack_images/000010.jpg
# 11            11    000011.jpg   ../ByteTrack_images/000011.jpg
# 12            12   0000122.jpg  ../ByteTrack_images/0000122.jpg
# 13            13    000013.jpg   ../ByteTrack_images/000013.jpg
# 14            14   0000142.jpg  ../ByteTrack_images/0000142.jpg
# 15            15   0000152.jpg  ../ByteTrack_images/0000152.jpg
# 16            16   0000162.jpg  ../ByteTrack_images/0000162.jpg
# 17             0    000000.jpg   ../ByteTrack_images/000000.jpg
# 18             1    000001.jpg   ../ByteTrack_images/000001.jpg
# 19             2    000002.jpg   ../ByteTrack_images/000002.jpg
#
#     exists_locally
# 0             True
# 1             True
# 2             True
# 3             True
# 4             True
# 5             True
# 6             True
# 7             True
# 8             True
# 9            False
# 10            True
# 11            True
# 12           False
# 13           False
# 14           False
# 15           False
# 16           False
# 17            True
# 18            True
# 19            True

# %%
def animate_track(sequence, track_id, delay=0.3, figsize=(10, 8)):
    """
    Animate a track frame by frame (in notebook).
    
    Args:
        sequence: Sequence name
        track_id: Track ID
        delay: Delay between frames in seconds
        figsize: Figure size
    """
    track_df = df[(df["sequence"] == sequence) & 
                  (df["track_id"] == track_id) & 
                  (df["exists_locally"])].copy()
    track_df = track_df.sort_values("frame_id_int")
    
    if len(track_df) == 0:
        print(f"No local images found for sequence={sequence}, track_id={track_id}")
        return
    
    print(f"Animating Track {track_id} from {sequence}")
    print(f"Total frames: {len(track_df)}")
    print(f"Frame range: {track_df['frame_id_int'].min()} - {track_df['frame_id_int'].max()}")
    print("Press Ctrl+C to stop\n")
    
    fig, ax = plt.subplots(figsize=figsize)
    
    try:
        for idx, row in track_df.iterrows():
            img = Image.open(row["local_path"])
            
            ax.clear()
            ax.imshow(img)
            ax.set_title(f"Track {track_id} | Frame {row['frame_id']} | Score: {row['score']:.3f}", 
                        fontsize=14, fontweight='bold')
            ax.axis('off')
            
            display(fig)
            clear_output(wait=True)
            time.sleep(delay)
    except KeyboardInterrupt:
        print("\nAnimation stopped")
    finally:
        plt.close(fig)

# %%
def show_track_grid(sequence, track_id, max_frames=20, cols=5, figsize=None, show_diagnostics=True):
    """
    Show track images in a grid layout with diagnostic info.
    
    Args:
        sequence: Sequence name
        track_id: Track ID
        max_frames: Maximum frames to show
        cols: Number of columns in grid
        figsize: Figure size (auto-calculated if None)
        show_diagnostics: Show bbox size and crop filename info
    """
    track_df = df[(df["sequence"] == sequence) & 
                  (df["track_id"] == track_id) & 
                  (df["exists_locally"])].copy()
    track_df = track_df.sort_values("frame_id_int").head(max_frames)
    
    if len(track_df) == 0:
        print(f"No local images found for sequence={sequence}, track_id={track_id}")
        return
    
    # Print diagnostic info
    if show_diagnostics:
        print(f"\nTrack {track_id} Diagnostics:")
        print(f"{'Frame':<8} {'Crop File':<15} {'BBox Size':<12} {'Crop Size':<12} {'Score':<8}")
        print("-" * 65)
        for _, row in track_df.iterrows():
            bbox_w = row['x2'] - row['x1']
            bbox_h = row['y2'] - row['y1']
            img = Image.open(row["local_path"])
            crop_w, crop_h = img.size
            print(f"{row['frame_id']:<8} {row['crop_filename']:<15} "
                  f"{bbox_w}x{bbox_h:<8} {crop_w}x{crop_h:<8} {row['score']:.3f}")
        print()
    
    n_frames = len(track_df)
    rows = (n_frames + cols - 1) // cols
    
    if figsize is None:
        figsize = (cols * 3, rows * 3.5)
    
    fig, axes = plt.subplots(rows, cols, figsize=figsize)
    
    # Handle single row/column cases
    if rows == 1 and cols == 1:
        axes = [[axes]]
    elif rows == 1:
        axes = [axes]
    elif cols == 1:
        axes = [[ax] for ax in axes]
    
    for idx, (_, row) in enumerate(track_df.iterrows()):
        r = idx // cols
        c = idx % cols
        ax = axes[r][c]
        
        img = Image.open(row["local_path"])
        crop_w, crop_h = img.size
        ax.imshow(img)
        
        # Show frame, crop filename, and size
        title = f"Frame {row['frame_id']}\n{row['crop_filename']}\n{crop_w}x{crop_h}px"
        ax.set_title(title, fontsize=8)
        ax.axis('off')
    
    # Hide empty subplots
    for idx in range(n_frames, rows * cols):
        r = idx // cols
        c = idx % cols
        axes[r][c].axis('off')
    
    plt.suptitle(f"Track {track_id} in {sequence}\n(Check if crops look consistent)", 
                 fontsize=14, fontweight='bold')
    plt.tight_layout()
    plt.show()

# %%
def create_gif(sequence, track_id, output_path="track_animation.gif", duration=200, max_frames=None):
    """
    Create an animated GIF from track images.
    
    Args:
        sequence: Sequence name
        track_id: Track ID
        output_path: Path to save GIF
        duration: Duration per frame in milliseconds
        max_frames: Max frames to include (None = all)
    """
    track_df = df[(df["sequence"] == sequence) & 
                  (df["track_id"] == track_id) & 
                  (df["exists_locally"])].copy()
    track_df = track_df.sort_values("frame_id_int")
    
    if max_frames:
        track_df = track_df.head(max_frames)
    
    if len(track_df) == 0:
        print(f"No local images found")
        return
    
    images = []
    for _, row in track_df.iterrows():
        img = Image.open(row["local_path"])
        # Add frame info to image
        from PIL import ImageDraw, ImageFont
        img_with_text = img.copy()
        draw = ImageDraw.Draw(img_with_text)
        text = f"Frame {row['frame_id']} | Score: {row['score']:.3f}"
        # Use default font
        draw.text((10, 10), text, fill='white')
        draw.text((10, 10), text, fill='black')  # Shadow effect
        images.append(img_with_text)
    
    # Save as GIF
    images[0].save(
        output_path,
        save_all=True,
        append_images=images[1:],
        duration=duration,
        loop=0
    )
    print(f"GIF saved to: {output_path}")
    print(f"Frames: {len(images)}, Duration: {duration}ms per frame")
    
    # Display in notebook
    return HTML(f'<img src="{output_path}">')

# %%
def compare_tracks_side_by_side(sequence, track_id_1, track_id_2, max_frames=10):
    """
    Show two tracks side by side for comparison.
    """
    track1 = df[(df["sequence"] == sequence) & 
                (df["track_id"] == track_id_1) & 
                (df["exists_locally"])].sort_values("frame_id_int").head(max_frames)
    
    track2 = df[(df["sequence"] == sequence) & 
                (df["track_id"] == track_id_2) & 
                (df["exists_locally"])].sort_values("frame_id_int").head(max_frames)
    
    n_frames = max(len(track1), len(track2))
    
    fig, axes = plt.subplots(2, n_frames, figsize=(n_frames * 2, 5))
    
    for i in range(n_frames):
        # Track 1
        if i < len(track1):
            row = track1.iloc[i]
            img = Image.open(row["local_path"])
            axes[0, i].imshow(img)
            axes[0, i].set_title(f"T{track_id_1} F{row['frame_id']}", fontsize=8)
        axes[0, i].axis('off')
        
        # Track 2
        if i < len(track2):
            row = track2.iloc[i]
            img = Image.open(row["local_path"])
            axes[1, i].imshow(img)
            axes[1, i].set_title(f"T{track_id_2} F{row['frame_id']}", fontsize=8)
        axes[1, i].axis('off')
    
    plt.tight_layout()
    plt.show()

# %%
if len(local_tracks) > 0:
    seq, tid = local_tracks.index[0]
    print("\n" + "="*60)
    print("Example 1: Grid view of first track")
    show_track_grid(seq, tid, max_frames=15, cols=5)
# Out:
# ============================================================
# Example 1: Grid view of first track
#
# Track 2 Diagnostics:
# Frame    Crop File       BBox Size    Crop Size    Score
# -----------------------------------------------------------------
# 0        000000.jpg      313x273      329x288      0.903
# 1        000001.jpg      313x273      329x288      0.905
# 2        000002.jpg      314x272      330x288      0.905
# 3        000003.jpg      313x272      329x288      0.903
# 4        000004.jpg      313x273      329x288      0.908
# 5        0000052.jpg     313x272      229x145      0.908
# 6        000006.jpg      314x273      330x288      0.904
# 7        0000072.jpg     313x272      240x140      0.902
# 8        0000082.jpg     313x273      244x142      0.906
# 9        000009.jpg      314x273      330x289      0.903
# 10       0000102.jpg     313x272      329x287      0.905
# 11       0000112.jpg     313x272      329x287      0.904
# 12       000012.jpg      313x273      329x289      0.904

# %%
animate_track(seq, tid, delay=0.3)

# %%
# Example 3: Create GIF (uncomment to use)
# create_gif(seq, tid, output_path="my_track.gif", duration=300, max_frames=20)

# Example 4: Compare two tracks (uncomment to use)
# if len(local_tracks) >= 2:
#     seq1, tid1 = local_tracks.index[0]
#     seq2, tid2 = local_tracks.index[1]
#     if seq1 == seq2:  # Same sequence
#         compare_tracks_side_by_side(seq1, tid1, tid2, max_frames=10)
